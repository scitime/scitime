# %%
from main import Estimator
from sklearn.ensemble import RandomForestRegressor
import numpy as np
import time
import pandas as pd

# %%
#Checking number of cores
estimator=Estimator(drop_rate=0.9999)

# %%
estimator.params
# Out:
# {'dummy_inputs': ['max_features'],
#  'external_params': {'num_features': [5, 50, 100],
#   'num_rows': [100, 1000, 10000]},
#  'internal_params': {'bootstrap': [True, False],
#   'max_depth': [10, 50, 100],
#   'max_features': ['auto', 10, 20, 50, 100],
#   'max_leaf_nodes': [2, 4, 10],
#   'min_impurity_decrease': [1, 5, 10],
#   'min_impurity_split': [1, 5, 10],
#   'min_samples_leaf': [1, 5, 10],
#   'min_samples_split': [2, 4, 10],
#   'min_weight_fraction_leaf': [0.1, 0.25, 0.5],
#   'n_estimators': [10, 50, 100],
#   'n_jobs': [1, 2, 5, 8],
#   'oob_score': [False]}}

# %%
estimator.estimation_inputs
# Out:
# ['num_rows',
#  'num_features',
#  'n_estimators',
#  'max_depth',
#  'min_samples_split',
#  'min_samples_leaf',
#  'min_weight_fraction_leaf',
#  'max_leaf_nodes',
#  'min_impurity_decrease',
#  'min_impurity_split',
#  'bootstrap',
#  'oob_score',
#  'n_jobs',
#  'max_features_auto',
#  'max_features_10',
#  'max_features_20',
#  'max_features_50',
#  'max_features_100']

# %%
estimator.rows_range=[100000]

# %%
df=estimator._generate_data()
# Out:
# 2018-10-15 21:11:43,611 - main.Estimator - Generating dummy training durations to create a training set
# 2018-10-15 21:11:43,897 - main.Estimator - data added for {'num_rows': 100, 'num_features': 5, 'n_estimators': 10, 'max_depth': 50, 'min_samples_split': 10, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.5, 'max_features': 'auto', 'max_leaf_nodes': 10, 'min_impurity_decrease': 5, 'min_impurity_split': 1, 'bootstrap': True, 'oob_score': False, 'n_jobs': 8} which outputs 0.11765480041503906 seconds
# 2018-10-15 21:11:44,455 - main.Estimator - data added for {'num_rows': 100, 'num_features': 5, 'n_estimators': 100, 'max_depth': 100, 'min_samples_split': 4, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.25, 'max_features': 'auto', 'max_leaf_nodes': 10, 'min_impurity_decrease': 1, 'min_impurity_split': 5, 'bootstrap': False, 'oob_score': False, 'n_jobs': 1} which outputs 0.07118391990661621 seconds
# ...

# %%
cd
# Out:
# /Users/nathantoubiana

# %%
cd Downloads/
# Out:
# /Users/nathantoubiana/Downloads

# %%
df=pd.read_csv('result.csv')
df2=pd.read_csv('result-2.csv')
cols=['num_rows',
'num_features','n_estimators',
'max_depth',
'min_samples_split',
'min_samples_leaf',
'min_weight_fraction_leaf',
'max_features',
'max_leaf_nodes',
'min_impurity_decrease',
'min_impurity_split',
'bootstrap',
'oob_score',
'n_jobs','output']
df.columns=cols
df2.columns=cols
df=pd.concat([df,df2])
outputs=df[['output']]
del df['output']

# %%
df.shape
# Out:
# (3623, 14)

# %%
cd
# Out:
# /Users/nathantoubiana

# %%
cd Documents/Codes/scikest/scikest/scikest
# Out:
# /Users/nathantoubiana/Documents/Codes/scikest/scikest/scikest

# %%
estimatorS=Estimator(algo_estimator='RF')

# %%
outputs.shape
# Out:
# (3623, 1)

# %%
estimatorS.estimation_inputs
# Out:
# ['num_rows',
#  'num_features',
#  'n_estimators',
#  'max_depth',
#  'min_samples_split',
#  'min_samples_leaf',
#  'min_weight_fraction_leaf',
#  'max_leaf_nodes',
#  'min_impurity_decrease',
#  'min_impurity_split',
#  'bootstrap',
#  'oob_score',
#  'n_jobs',
#  'max_features_auto',
#  'max_features_10',
#  'max_features_20',
#  'max_features_50',
#  'max_features_100']

# %%
df.head()
# Out:
#    num_rows  num_features  n_estimators  max_depth  min_samples_split  \
# 0    100000             5            10         10                  4
# 1    100000             5            10         10                 10
# 2    100000             5            10         10                 10
# 3    100000             5            10         10                 10
# 4    100000             5            10         10                 10
#
#    min_samples_leaf  min_weight_fraction_leaf max_features  max_leaf_nodes  \
# 0                 1                      0.25         auto              10
# 1                 1                      0.25         auto               2
# 2                 1                      0.50         auto               2
# 3                 5                      0.50         auto              10
# 4                10                      0.50         auto              10
#
#    min_impurity_decrease  min_impurity_split  bootstrap  oob_score  n_jobs
# ...

# %%
estimatorS._model_fit(generate_data=False,outputs=outputs,df=df)
# Out:
# 2018-10-15 21:12:14,705 - main.Estimator - Model inputs: ['num_rows', 'num_features', 'n_estimators', 'max_depth', 'min_samples_split', 'min_samples_leaf', 'min_weight_fraction_leaf', 'max_leaf_nodes', 'min_impurity_decrease', 'min_impurity_split', 'bootstrap', 'oob_score', 'n_jobs', 'max_features_10', 'max_features_20', 'max_features_50', 'max_features_auto']
# 2018-10-15 21:12:14,707 - main.Estimator - Fitting RF to estimate training durations
# 2018-10-15 21:12:14,792 - main.Estimator - Saving RF to RF_estimator.pkl
# 2018-10-15 21:12:14,810 - main.Estimator - R squared on train set is 0.9982796062655388
# 2018-10-15 21:12:14,820 - main.Estimator - MAPE on train set is: 1.3987783766484696
# 2018-10-15 21:12:14,821 - main.Estimator - MAPE on test set is: 3.341181296114913
# 2018-10-15 21:12:14,823 - main.Estimator - RMSE on train set is 0.6673970875680879
# 2018-10-15 21:12:14,824 - main.Estimator - RMSE on test set is 2.464598698594717
# ...

# %%
estimatorS.params
# Out:
# {'dummy_inputs': ['max_features'],
#  'external_params': {'num_features': [5, 50, 100],
#   'num_rows': [100, 1000, 10000]},
#  'internal_params': {'bootstrap': [True, False],
#   'max_depth': [10, 50, 100],
#   'max_features': ['auto', 10, 20, 50, 100],
#   'max_leaf_nodes': [2, 4, 10],
#   'min_impurity_decrease': [1, 5, 10],
#   'min_impurity_split': [1, 5, 10],
#   'min_samples_leaf': [1, 5, 10],
#   'min_samples_split': [2, 4, 10],
#   'min_weight_fraction_leaf': [0.1, 0.25, 0.5],
#   'n_estimators': [10, 50, 100],
#   'n_jobs': [1, 2, 5, 8],
#   'oob_score': [False]}}

# %%
p=estimatorS.params['internal_params']

# %%
v=estimatorS.params['dummy_inputs']

# %%
v=estimatorS.params['dummy_inputs']
p=estimatorS.params['internal_params']
[i for i in p.keys() if i not in v]+[i+'_'+str(k) for i in p.keys() if i in v for k in p[i]]
# Out:
# ['n_estimators',
#  'max_depth',
#  'min_samples_split',
#  'min_samples_leaf',
#  'min_weight_fraction_leaf',
#  'max_leaf_nodes',
#  'min_impurity_decrease',
#  'min_impurity_split',
#  'bootstrap',
#  'oob_score',
#  'n_jobs',
#  'max_features_auto',
#  'max_features_10',
#  'max_features_20',
#  'max_features_50',
#  'max_features_100']

# %%
df.tail(2)
# Out:
#       num_rows  num_features  n_estimators  max_depth  min_samples_split  \
# 2605  10000000           100           100        200                 10
# 2606  10000000           100           100        200                 10
#
#       min_samples_leaf  min_weight_fraction_leaf max_features  max_leaf_nodes  \
# 2605                10                      0.25           20               4
# 2606                10                      0.50         auto              10
#
#       min_impurity_decrease  min_impurity_split  bootstrap  oob_score  n_jobs
# 2605                      5                   5       True      False       8
# 2606                     10                  10       True      False       1

# %%
rf= RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=200,
           max_features='auto', max_leaf_nodes=10, min_impurity_decrease=10,
           min_impurity_split=10, min_samples_leaf=10,
           min_samples_split=10, min_weight_fraction_leaf=0.5,
           n_estimators=100, n_jobs=1, oob_score=False, random_state=None,
           verbose=0, warm_start=False)

# %%
estimatorS.estimate_duration(np.random.rand(10000000,10),rf)
# Out:
# 2018-10-15 21:12:45,041 - main.Estimator - Fetching estimator: RF_estimator.pkl
# 2018-10-15 21:12:45,053 - main.Estimator - Training your model for these params: {'num_rows': [10000000], 'num_features': [10], 'n_estimators': [100], 'max_depth': [200], 'min_samples_split': [10], 'min_samples_leaf': [10], 'min_weight_fraction_leaf': [0.5], 'max_features': ['auto'], 'max_leaf_nodes': [10], 'min_impurity_decrease': [10], 'min_impurity_split': [10], 'bootstrap': [True], 'oob_score': [False], 'n_jobs': [1]}
# 2018-10-15 21:12:45,064 - main.Estimator - Training your model should take ~ 82.6235397577 seconds
# array([ 82.62353976])

# %%
estimatorS.algo_estimator
# Out:
# 'RF'

# %%
X,y=np.random.rand(10000000,10),np.random.rand(10000000,1)
start_time = time.time()
rf.fit(X,y)
elapsed_time = time.time() - start_time

# %%
elapsed_time

# %%
outputs.tail(100)
# Out:
#          output
# 2507  27.990400
# 2508   7.038882
# 2509   7.089946
# 2510   6.776549
# 2511  14.106352
# 2512   7.116777
# 2513   7.031685
# 2514  51.482451
# 2515  10.460579
# 2516  91.108263
# 2517  13.636258
# 2518  13.415228
# 2519  27.763313
# 2520  26.960358
# 2521  87.911498
# 2522   9.813354
# 2523  27.869259
# 2524  10.271406
# 2525   9.961675
# 2526  10.593755
# 2527  51.827018
# 2528  85.407759
# 2529  10.424347
# 2530  10.541711
# 2531  27.183438
# 2532   9.986944
# 2533   9.862441
# 2534  26.908265
# 2535  50.160006
# 2536   9.335468
# ...         ...
# 2577  13.066576
# 2578  83.341798
# 2579  49.416020
# 2580  10.167551
# 2581  26.941765
# 2582  84.516469
# 2583  85.098203
# 2584   9.851790
# 2585  13.032985
# 2586  85.044441
# 2587  26.652886
# 2588   9.934242
# 2589  27.970823
# 2590  28.239923
# 2591  22.527636
# 2592  14.333293
# 2593  10.005458
# 2594  51.341994
# 2595   9.939292
# 2596  22.147537
# 2597  50.220989
# 2598  22.150665
# 2599  13.379145
# ...

# %%
df.tail(100)
# Out:
#       num_rows  num_features  n_estimators  max_depth  min_samples_split  \
# 2507  10000000           100            50        200                 10
# 2508  10000000           100            50        200                 10
# 2509  10000000           100            50        200                 10
# 2510  10000000           100            50        200                 10
# 2511  10000000           100            50        200                 10
# 2512  10000000           100            50        200                 10
# 2513  10000000           100            50        200                 10
# 2514  10000000           100           100         10                  2
# 2515  10000000           100           100         10                  2
# 2516  10000000           100           100         10                  2
# 2517  10000000           100           100         10                  2
# 2518  10000000           100           100         10                  2
# ...
