# %%
from main import RFest
from sklearn.ensemble import RandomForestRegressor
import numpy as np
import time
import pandas as pd

# %%
#Checking number of cores
estimator=RFest(drop_rate=0.9999)

# %%
estimator.params
# Out:
# {'dummy_inputs': ['max_features'],
#  'external_params': {'num_features': [5, 50, 100],
#   'num_rows': [100, 1000, 10000]},
#  'internal_params': {'bootstrap': [True, False],
#   'max_depth': [10, 50, 100],
#   'max_features': ['auto', 10, 20, 50],
#   'max_leaf_nodes': [2, 4, 10],
#   'min_impurity_decrease': [1, 5, 10],
#   'min_impurity_split': [1, 5, 10],
#   'min_samples_leaf': [1, 5, 10],
#   'min_samples_split': [2, 4, 10],
#   'min_weight_fraction_leaf': [0.1, 0.25, 0.5],
#   'n_estimators': [10, 50, 100],
#   'n_jobs': [1, 2, 5, 8],
#   'oob_score': [False]}}

# %%
estimator.estimation_inputs
# Out:
# ['num_rows',
#  'num_features',
#  'n_estimators',
#  'max_depth',
#  'min_samples_split',
#  'min_samples_leaf',
#  'min_weight_fraction_leaf',
#  'max_leaf_nodes',
#  'min_impurity_decrease',
#  'min_impurity_split',
#  'bootstrap',
#  'oob_score',
#  'n_jobs',
#  'max_features_auto',
#  'max_features_10',
#  'max_features_20',
#  'max_features_50']

# %%
estimator.rows_range=[100000]

# %%
df=estimator._generate_data()
# Out:
# 2018-10-13 15:08:57,378 - main.RFest - Generating dummy training durations to create a training set
# 2018-10-13 15:08:57,608 - main.RFest - data added for {'num_rows': 100, 'num_features': 5, 'n_estimators': 10, 'max_depth': 50, 'min_samples_split': 10, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.5, 'max_features': 'auto', 'max_leaf_nodes': 10, 'min_impurity_decrease': 5, 'min_impurity_split': 5, 'bootstrap': True, 'oob_score': False, 'n_jobs': 2} which outputs 0.11368703842163086 seconds
# 2018-10-13 15:08:57,962 - main.RFest - data added for {'num_rows': 100, 'num_features': 5, 'n_estimators': 50, 'max_depth': 100, 'min_samples_split': 2, 'min_samples_leaf': 10, 'min_weight_fraction_leaf': 0.25, 'max_features': 'auto', 'max_leaf_nodes': 2, 'min_impurity_decrease': 5, 'min_impurity_split': 5, 'bootstrap': False, 'oob_score': False, 'n_jobs': 8} which outputs 0.13915491104125977 seconds
# 2018-10-13 15:08:58,252 - main.RFest - data added for {'num_rows': 100, 'num_features': 5, 'n_estimators': 100, 'max_depth': 100, 'min_samples_split': 4, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.25, 'max_features': 'auto', 'max_leaf_nodes': 4, 'min_impurity_decrease': 10, 'min_impurity_split': 5, 'bootstrap': True, 'oob_score': False, 'n_jobs': 1} which outputs 0.06952619552612305 seconds
# 2018-10-13 15:08:58,418 - main.RFest - data added for {'num_rows': 100, 'num_features': 50, 'n_estimators': 10, 'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.25, 'max_features': 'auto', 'max_leaf_nodes': 10, 'min_impurity_decrease': 5, 'min_impurity_split': 10, 'bootstrap': False, 'oob_score': False, 'n_jobs': 5} which outputs 0.10760378837585449 seconds
# 2018-10-13 15:08:58,580 - main.RFest - data added for {'num_rows': 100, 'num_features': 50, 'n_estimators': 10, 'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 10, 'min_weight_fraction_leaf': 0.5, 'max_features': 50, 'max_leaf_nodes': 10, 'min_impurity_decrease': 1, 'min_impurity_split': 1, 'bootstrap': True, 'oob_score': False, 'n_jobs': 8} which outputs 0.11297297477722168 seconds
# 2018-10-13 15:08:58,699 - main.RFest - data added for {'num_rows': 100, 'num_features': 50, 'n_estimators': 10, 'max_depth': 50, 'min_samples_split': 2, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.25, 'max_features': 20, 'max_leaf_nodes': 10, 'min_impurity_decrease': 1, 'min_impurity_split': 5, 'bootstrap': True, 'oob_score': False, 'n_jobs': 5} which outputs 0.10977792739868164 seconds
# 2018-10-13 15:08:58,845 - main.RFest - data added for {'num_rows': 100, 'num_features': 50, 'n_estimators': 10, 'max_depth': 50, 'min_samples_split': 4, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.25, 'max_features': 50, 'max_leaf_nodes': 4, 'min_impurity_decrease': 1, 'min_impurity_split': 10, 'bootstrap': True, 'oob_score': False, 'n_jobs': 8} which outputs 0.10940003395080566 seconds
# 2018-10-13 15:08:58,891 - main.RFest - data added for {'num_rows': 100, 'num_features': 50, 'n_estimators': 10, 'max_depth': 50, 'min_samples_split': 10, 'min_samples_leaf': 10, 'min_weight_fraction_leaf': 0.25, 'max_features': 50, 'max_leaf_nodes': 2, 'min_impurity_decrease': 10, 'min_impurity_split': 5, 'bootstrap': True, 'oob_score': False, 'n_jobs': 1} which outputs 0.009040117263793945 seconds
# 2018-10-13 15:08:59,009 - main.RFest - data added for {'num_rows': 100, 'num_features': 50, 'n_estimators': 10, 'max_depth': 100, 'min_samples_split': 2, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.25, 'max_features': 50, 'max_leaf_nodes': 2, 'min_impurity_decrease': 10, 'min_impurity_split': 1, 'bootstrap': False, 'oob_score': False, 'n_jobs': 2} which outputs 0.10883402824401855 seconds
# 2018-10-13 15:08:59,133 - main.RFest - data added for {'num_rows': 100, 'num_features': 50, 'n_estimators': 10, 'max_depth': 100, 'min_samples_split': 2, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.1, 'max_features': 'auto', 'max_leaf_nodes': 2, 'min_impurity_decrease': 10, 'min_impurity_split': 10, 'bootstrap': False, 'oob_score': False, 'n_jobs': 2} which outputs 0.11590814590454102 seconds
# 2018-10-13 15:08:59,263 - main.RFest - data added for {'num_rows': 100, 'num_features': 50, 'n_estimators': 10, 'max_depth': 100, 'min_samples_split': 2, 'min_samples_leaf': 10, 'min_weight_fraction_leaf': 0.5, 'max_features': 20, 'max_leaf_nodes': 4, 'min_impurity_decrease': 10, 'min_impurity_split': 5, 'bootstrap': True, 'oob_score': False, 'n_jobs': 8} which outputs 0.11066007614135742 seconds
# 2018-10-13 15:08:59,402 - main.RFest - data added for {'num_rows': 100, 'num_features': 50, 'n_estimators': 10, 'max_depth': 100, 'min_samples_split': 4, 'min_samples_leaf': 10, 'min_weight_fraction_leaf': 0.5, 'max_features': 10, 'max_leaf_nodes': 4, 'min_impurity_decrease': 5, 'min_impurity_split': 10, 'bootstrap': True, 'oob_score': False, 'n_jobs': 8} which outputs 0.11170792579650879 seconds
# 2018-10-13 15:08:59,582 - main.RFest - data added for {'num_rows': 100, 'num_features': 50, 'n_estimators': 50, 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.5, 'max_features': 10, 'max_leaf_nodes': 2, 'min_impurity_decrease': 1, 'min_impurity_split': 5, 'bootstrap': True, 'oob_score': False, 'n_jobs': 8} which outputs 0.13736820220947266 seconds
# 2018-10-13 15:08:59,731 - main.RFest - data added for {'num_rows': 100, 'num_features': 50, 'n_estimators': 50, 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 10, 'min_weight_fraction_leaf': 0.1, 'max_features': 20, 'max_leaf_nodes': 10, 'min_impurity_decrease': 10, 'min_impurity_split': 1, 'bootstrap': False, 'oob_score': False, 'n_jobs': 8} which outputs 0.14209222793579102 seconds
# 2018-10-13 15:08:59,878 - main.RFest - data added for {'num_rows': 100, 'num_features': 50, 'n_estimators': 50, 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 10, 'min_weight_fraction_leaf': 0.25, 'max_features': 10, 'max_leaf_nodes': 2, 'min_impurity_decrease': 5, 'min_impurity_split': 10, 'bootstrap': False, 'oob_score': False, 'n_jobs': 5} which outputs 0.14186406135559082 seconds
# 2018-10-13 15:09:00,045 - main.RFest - data added for {'num_rows': 100, 'num_features': 50, 'n_estimators': 50, 'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.1, 'max_features': 10, 'max_leaf_nodes': 4, 'min_impurity_decrease': 10, 'min_impurity_split': 1, 'bootstrap': False, 'oob_score': False, 'n_jobs': 5} which outputs 0.13619399070739746 seconds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-6e2158e4072b> in <module>()
# ----> 1 df=estimator._generate_data()
#
# ~/Documents/Codes/scikest/scikest/scikest/utils.py in timed(*args, **kw)
#      21     def timed(*args, **kw):
#      22         ts = time.time()
# ---> 23         result = method(*args, **kw)
#      24         te = time.time()
#      25         log.logger.info(f'{method.__qualname__} took {round(te - ts, 3)}s seconds')
#
# ~/Documents/Codes/scikest/scikest/scikest/main.py in _generate_data(self)
#      92                 #Handling max_features > p case
#      93                 if self._check_feature_condition(f,p):
# ---> 94                     thisOutput = self._measure_time(n, p, rf_parameters_dic)
#      95                     thisInput = permutation
#      96                     outputs.append(thisOutput)
#
# ~/Documents/Codes/scikest/scikest/scikest/main.py in _measure_time(self, n, p, rf_params)
#      61         clf = RandomForestRegressor(**rf_params)
#      62         start_time = time.time()
# ---> 63         clf.fit(X, y)
#      64         elapsed_time = time.time() - start_time
#      65         return elapsed_time
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     314             for i in range(n_more_estimators):
#     315                 tree = self._make_estimator(append=False,
# --> 316                                             random_state=random_state)
#     317                 trees.append(tree)
#     318
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/base.py in _make_estimator(self, append, random_state)
#     123         sub-estimators.
#     124         """
# --> 125         estimator = clone(self.base_estimator_)
#     126         estimator.set_params(**dict((p, getattr(self, p))
#     127                                     for p in self.estimator_params))
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/base.py in clone(estimator, safe)
#      58                             % (repr(estimator), type(estimator)))
#      59     klass = estimator.__class__
# ---> 60     new_object_params = estimator.get_params(deep=False)
#      61     for name, param in six.iteritems(new_object_params):
#      62         new_object_params[name] = clone(param, safe=False)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/base.py in get_params(self, deep)
#     239                     continue
#     240             finally:
# --> 241                 warnings.filters.pop(0)
#     242
#     243             # XXX: should we rather test if instance of estimator?
#
# KeyboardInterrupt:

# %%
cd
# Out:
# /Users/nathantoubiana

# %%
cd Downloads/
# Out:
# /Users/nathantoubiana/Downloads

# %%
df=pd.read_csv('result.csv')
df2=pd.read_csv('result-2.csv')
cols=['num_rows',
'num_features','n_estimators',
'max_depth',
'min_samples_split',
'min_samples_leaf',
'min_weight_fraction_leaf',
'max_features',
'max_leaf_nodes',
'min_impurity_decrease',
'min_impurity_split',
'bootstrap',
'oob_score',
'n_jobs','output']
df.columns=cols
df2.columns=cols
df=pd.concat([df,df2])
outputs=df[['output']]
del df['output']

# %%
df.shape
# Out:
# (3623, 14)

# %%
cd
# Out:
# /Users/nathantoubiana

# %%
cd Documents/Codes/scikest/scikest/scikest
# Out:
# /Users/nathantoubiana/Documents/Codes/scikest/scikest/scikest

# %%
estimatorS=RFest(algo_estimator='RF')

# %%
outputs.shape
# Out:
# (3623, 1)

# %%
estimatorS.estimation_inputs
# Out:
# ['num_rows',
#  'num_features',
#  'n_estimators',
#  'max_depth',
#  'min_samples_split',
#  'min_samples_leaf',
#  'min_weight_fraction_leaf',
#  'max_leaf_nodes',
#  'min_impurity_decrease',
#  'min_impurity_split',
#  'bootstrap',
#  'oob_score',
#  'n_jobs',
#  'max_features_auto',
#  'max_features_10',
#  'max_features_20',
#  'max_features_50']

# %%
df.head()
# Out:
#    num_rows  num_features  n_estimators  max_depth  min_samples_split  \
# 0    100000             5            10         10                  4
# 1    100000             5            10         10                 10
# 2    100000             5            10         10                 10
# 3    100000             5            10         10                 10
# 4    100000             5            10         10                 10
#
#    min_samples_leaf  min_weight_fraction_leaf max_features  max_leaf_nodes  \
# 0                 1                      0.25         auto              10
# 1                 1                      0.25         auto               2
# 2                 1                      0.50         auto               2
# 3                 5                      0.50         auto              10
# 4                10                      0.50         auto              10
#
#    min_impurity_decrease  min_impurity_split  bootstrap  oob_score  n_jobs
# 0                      1                  10      False      False       8
# 1                     10                   5      False      False       2
# 2                     10                   5       True      False       2
# 3                      5                  10      False      False       8
# 4                     10                   5       True      False       5

# %%
estimatorS._model_fit(generate_data=False,outputs=outputs,df=df)
# Out:
# 2018-10-13 15:09:10,730 - main.RFest - Model inputs: ['num_rows', 'num_features', 'n_estimators', 'max_depth', 'min_samples_split', 'min_samples_leaf', 'min_weight_fraction_leaf', 'max_leaf_nodes', 'min_impurity_decrease', 'min_impurity_split', 'bootstrap', 'oob_score', 'n_jobs', 'max_features_10', 'max_features_20', 'max_features_50', 'max_features_auto']
# 2018-10-13 15:09:10,732 - main.RFest - Fitting RF to estimate training durations
# 2018-10-13 15:09:10,812 - main.RFest - Saving RF to RF_estimator.pkl
# 2018-10-13 15:09:10,826 - main.RFest - R squared on train set is 0.9995555161233945
# 2018-10-13 15:09:10,836 - main.RFest - MAPE on train set is: 1.3669507105205025
# 2018-10-13 15:09:10,838 - main.RFest - MAPE on test set is: 3.436826044813077
# 2018-10-13 15:09:10,839 - main.RFest - RMSE on train set is 0.33923322953786217
# 2018-10-13 15:09:10,841 - main.RFest - RMSE on test set is 1.2795397371039503
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
estimatorS.params
# Out:
# {'dummy_inputs': ['max_features'],
#  'external_params': {'num_features': [5, 50, 100],
#   'num_rows': [100, 1000, 10000]},
#  'internal_params': {'bootstrap': [True, False],
#   'max_depth': [10, 50, 100],
#   'max_features': ['auto', 10, 20, 50],
#   'max_leaf_nodes': [2, 4, 10],
#   'min_impurity_decrease': [1, 5, 10],
#   'min_impurity_split': [1, 5, 10],
#   'min_samples_leaf': [1, 5, 10],
#   'min_samples_split': [2, 4, 10],
#   'min_weight_fraction_leaf': [0.1, 0.25, 0.5],
#   'n_estimators': [10, 50, 100],
#   'n_jobs': [1, 2, 5, 8],
#   'oob_score': [False]}}

# %%
p=estimatorS.params['internal_params']

# %%
v=estimatorS.params['dummy_inputs']

# %%
v=estimatorS.params['dummy_inputs']
p=estimatorS.params['internal_params']
[i for i in p.keys() if i not in v]+[i+'_'+str(k) for i in p.keys() if i in v for k in p[i]]
# Out:
# ['n_estimators',
#  'max_depth',
#  'min_samples_split',
#  'min_samples_leaf',
#  'min_weight_fraction_leaf',
#  'max_leaf_nodes',
#  'min_impurity_decrease',
#  'min_impurity_split',
#  'bootstrap',
#  'oob_score',
#  'n_jobs',
#  'max_features_auto',
#  'max_features_10',
#  'max_features_20',
#  'max_features_50']

# %%
df.tail(2)
# Out:
#       num_rows  num_features  n_estimators  max_depth  min_samples_split  \
# 2605  10000000           100           100        200                 10
# 2606  10000000           100           100        200                 10
#
#       min_samples_leaf  min_weight_fraction_leaf max_features  max_leaf_nodes  \
# 2605                10                      0.25           20               4
# 2606                10                      0.50         auto              10
#
#       min_impurity_decrease  min_impurity_split  bootstrap  oob_score  n_jobs
# 2605                      5                   5       True      False       8
# 2606                     10                  10       True      False       1

# %%
rf= RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=200,
           max_features='auto', max_leaf_nodes=10, min_impurity_decrease=10,
           min_impurity_split=10, min_samples_leaf=10,
           min_samples_split=10, min_weight_fraction_leaf=0.5,
           n_estimators=100, n_jobs=1, oob_score=False, random_state=None,
           verbose=0, warm_start=False)

# %%
estimatorS.estimate_duration(np.random.rand(100000,100),rf)
# Out:
# 2018-10-13 15:14:55,340 - main.RFest - Fetching estimator: RF_estimator.pkl
# 2018-10-13 15:14:55,353 - main.RFest - Training your model for these params: {'num_rows': [100000], 'num_features': [100], 'n_estimators': [100], 'max_depth': [200], 'min_samples_split': [10], 'min_samples_leaf': [10], 'min_weight_fraction_leaf': [0.5], 'max_features': ['auto'], 'max_leaf_nodes': [10], 'min_impurity_decrease': [10], 'min_impurity_split': [10], 'bootstrap': [True], 'oob_score': [False], 'n_jobs': [1]}
# 2018-10-13 15:14:55,366 - main.RFest - Training your model should take ~ 0.382826519012 seconds
# array([ 0.38282652])

# %%
estimatorS.algo_estimator
# Out:
# 'RF'

# %%
X,y=np.random.rand(10000000,10),np.random.rand(10000000,1)
start_time = time.time()
rf.fit(X,y)
elapsed_time = time.time() - start_time

# %%
elapsed_time
# Out:
# 67.73310685157776

# %%
outputs.tail(100)
# Out:
#          output
# 2507  27.990400
# 2508   7.038882
# 2509   7.089946
# 2510   6.776549
# 2511  14.106352
# 2512   7.116777
# 2513   7.031685
# 2514  51.482451
# 2515  10.460579
# 2516  91.108263
# 2517  13.636258
# 2518  13.415228
# 2519  27.763313
# 2520  26.960358
# 2521  87.911498
# 2522   9.813354
# 2523  27.869259
# 2524  10.271406
# 2525   9.961675
# 2526  10.593755
# 2527  51.827018
# 2528  85.407759
# 2529  10.424347
# 2530  10.541711
# 2531  27.183438
# 2532   9.986944
# 2533   9.862441
# 2534  26.908265
# 2535  50.160006
# 2536   9.335468
# ...         ...
# 2577  13.066576
# 2578  83.341798
# 2579  49.416020
# 2580  10.167551
# 2581  26.941765
# 2582  84.516469
# 2583  85.098203
# 2584   9.851790
# 2585  13.032985
# 2586  85.044441
# 2587  26.652886
# 2588   9.934242
# 2589  27.970823
# 2590  28.239923
# 2591  22.527636
# 2592  14.333293
# 2593  10.005458
# 2594  51.341994
# 2595   9.939292
# 2596  22.147537
# 2597  50.220989
# 2598  22.150665
# 2599  13.379145
# 2600  50.631554
# 2601  28.092760
# 2602  85.849083
# 2603  26.903155
# 2604   9.902700
# 2605  21.908098
# 2606  89.199514
#
# [100 rows x 1 columns]

# %%
df.tail(100)
# Out:
#       num_rows  num_features  n_estimators  max_depth  min_samples_split  \
# 2507  10000000           100            50        200                 10
# 2508  10000000           100            50        200                 10
# 2509  10000000           100            50        200                 10
# 2510  10000000           100            50        200                 10
# 2511  10000000           100            50        200                 10
# 2512  10000000           100            50        200                 10
# 2513  10000000           100            50        200                 10
# 2514  10000000           100           100         10                  2
# 2515  10000000           100           100         10                  2
# 2516  10000000           100           100         10                  2
# 2517  10000000           100           100         10                  2
# 2518  10000000           100           100         10                  2
# 2519  10000000           100           100         10                  2
# 2520  10000000           100           100         10                  2
# 2521  10000000           100           100         10                  4
# 2522  10000000           100           100         10                  4
# 2523  10000000           100           100         10                  4
# 2524  10000000           100           100         10                  4
# 2525  10000000           100           100         10                  4
# 2526  10000000           100           100         10                  4
# 2527  10000000           100           100         10                  4
# 2528  10000000           100           100         10                  4
# 2529  10000000           100           100         10                  4
# 2530  10000000           100           100         10                 10
# 2531  10000000           100           100         10                 10
# 2532  10000000           100           100         10                 10
# 2533  10000000           100           100         10                 10
# 2534  10000000           100           100         10                 10
# 2535  10000000           100           100         10                 10
# 2536  10000000           100           100         10                 10
# ...        ...           ...           ...        ...                ...
# 2577  10000000           100           100        100                 10
# 2578  10000000           100           100        100                 10
# 2579  10000000           100           100        100                 10
# 2580  10000000           100           100        100                 10
# 2581  10000000           100           100        100                 10
# 2582  10000000           100           100        100                 10
# 2583  10000000           100           100        200                  2
# 2584  10000000           100           100        200                  2
# 2585  10000000           100           100        200                  2
# 2586  10000000           100           100        200                  2
# 2587  10000000           100           100        200                  2
# 2588  10000000           100           100        200                  2
# 2589  10000000           100           100        200                  2
# 2590  10000000           100           100        200                  2
# 2591  10000000           100           100        200                  2
# 2592  10000000           100           100        200                  4
# 2593  10000000           100           100        200                  4
# 2594  10000000           100           100        200                  4
# 2595  10000000           100           100        200                  4
# 2596  10000000           100           100        200                  4
# 2597  10000000           100           100        200                  4
# 2598  10000000           100           100        200                  4
# 2599  10000000           100           100        200                  4
# 2600  10000000           100           100        200                  4
# 2601  10000000           100           100        200                 10
# 2602  10000000           100           100        200                 10
# 2603  10000000           100           100        200                 10
# 2604  10000000           100           100        200                 10
# 2605  10000000           100           100        200                 10
# 2606  10000000           100           100        200                 10
#
#       min_samples_leaf  min_weight_fraction_leaf max_features  max_leaf_nodes  \
# 2507                 5                      0.50         auto              10
# 2508                 5                      0.50           50               4
# 2509                10                      0.10           20               4
# 2510                10                      0.25         auto               4
# 2511                10                      0.25           20               2
# 2512                10                      0.25           50               4
# 2513                10                      0.50           20               4
# 2514                 1                      0.10         auto               2
# 2515                 1                      0.10           20               4
# 2516                 1                      0.25           10               4
# 2517                 1                      0.50           20               2
# 2518                 1                      0.50           20               2
# 2519                 5                      0.10         auto              10
# 2520                10                      0.10           20              10
# 2521                 1                      0.10         auto              10
# 2522                 1                      0.10           20               2
# 2523                 1                      0.25           20               4
# 2524                 1                      0.25           50               2
# 2525                 1                      0.50           10               2
# 2526                 5                      0.10           20               4
# 2527                 5                      0.10           20              10
# 2528                 5                      0.50         auto               4
# 2529                10                      0.25           50               4
# 2530                 1                      0.10           10               4
# 2531                 1                      0.10           20               4
# 2532                 1                      0.10           20              10
# 2533                 1                      0.25           10               2
# 2534                 1                      0.25           50               2
# 2535                 1                      0.50           20               4
# 2536                 5                      0.10         auto               4
# ...                ...                       ...          ...             ...
# 2577                10                      0.10           20              10
# 2578                10                      0.10           50               4
# 2579                10                      0.25           20              10
# 2580                10                      0.50           10              10
# 2581                10                      0.50           20              10
# 2582                10                      0.50           50               4
# 2583                 1                      0.10           20              10
# 2584                 1                      0.25           50               2
# 2585                 1                      0.50         auto               4
# 2586                 5                      0.10           50               4
# 2587                 5                      0.10           50               4
# 2588                 5                      0.25           50               2
# 2589                10                      0.10         auto              10
# 2590                10                      0.10           10               4
# 2591                10                      0.10           20               4
# 2592                 1                      0.10         auto               2
# 2593                 1                      0.10           20               4
# 2594                 1                      0.25         auto               2
# 2595                 1                      0.50           50              10
# 2596                 5                      0.10           50              10
# 2597                 5                      0.25           10               2
# 2598                 5                      0.25           20              10
# 2599                 5                      0.50           10               2
# 2600                10                      0.50           50               2
# 2601                 1                      0.10         auto               2
# 2602                 1                      0.10           50               2
# 2603                 5                      0.25         auto               4
# 2604                 5                      0.50         auto               2
# 2605                10                      0.25           20               4
# 2606                10                      0.50         auto              10
#
#       min_impurity_decrease  min_impurity_split  bootstrap  oob_score  n_jobs
# 2507                      1                   1       True      False       2
# 2508                     10                   1      False      False       5
# 2509                     10                   1      False      False       5
# 2510                      1                   1      False      False       8
# 2511                      1                   5       True      False       8
# 2512                      1                   1      False      False       2
# 2513                      5                  10      False      False       2
# 2514                     10                   5       True      False       2
# 2515                      5                   5      False      False       8
# 2516                      5                   5       True      False       1
# 2517                      5                   1      False      False       1
# 2518                     10                  10      False      False       1
# 2519                     10                  10       True      False       5
# 2520                      1                   1       True      False       5
# 2521                     10                  10       True      False       1
# 2522                      5                   5      False      False       2
# 2523                     10                   5       True      False       5
# 2524                     10                  10      False      False       8
# 2525                     10                   1      False      False       8
# 2526                     10                   5      False      False       2
# 2527                      5                   1       True      False       2
# 2528                      5                   5       True      False       1
# 2529                      5                   1      False      False       8
# 2530                      5                   5      False      False       8
# 2531                      1                   5       True      False       5
# 2532                      1                   5      False      False       8
# 2533                     10                   1      False      False       8
# 2534                     10                  10       True      False       5
# 2535                      5                   5       True      False       2
# 2536                      1                   5      False      False       2
# ...                     ...                 ...        ...        ...     ...
# 2577                     10                   1      False      False       1
# 2578                     10                   5       True      False       1
# 2579                      1                   1       True      False       2
# 2580                      1                  10      False      False       5
# 2581                      1                   1       True      False       5
# 2582                      1                  10       True      False       1
# 2583                      5                  10       True      False       1
# 2584                      1                   1      False      False       2
# 2585                      1                   1      False      False       1
# 2586                      1                   5       True      False       1
# 2587                      1                   5       True      False       5
# 2588                      1                   5      False      False       5
# 2589                      5                  10       True      False       5
# 2590                     10                  10       True      False       5
# 2591                     10                   1       True      False       8
# 2592                      5                   5      False      False       1
# 2593                      5                  10      False      False       2
# 2594                      1                  10       True      False       2
# 2595                      5                   1      False      False       2
# 2596                      1                   5       True      False       8
# 2597                     10                   5       True      False       2
# 2598                     10                  10       True      False       8
# 2599                      1                   5      False      False       1
# 2600                      5                   1       True      False       2
# 2601                      1                  10       True      False       5
# 2602                      1                   5       True      False       1
# 2603                      1                  10       True      False       5
# 2604                      1                   1      False      False       2
# 2605                      5                   5       True      False       8
# 2606                     10                  10       True      False       1
#
# [100 rows x 14 columns]
